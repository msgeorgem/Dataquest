# %%
import pandas as pd
hn = pd.read_csv('hacker_news.csv')
hn.head(3)
# Out:
#          id                                              title  \
# 0  12224879                          Interactive Dynamic Video
# 1  11964716  Florida DJs May Face Felony for April Fools' W...
# 2  11919867       Technology ventures: From Idea to Enterprise
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/         386
# 1  http://www.thewire.com/entertainment/2013/04/f...           2
# 2  https://www.amazon.com/Technology-Ventures-Ent...           3
#
#    num_comments    author       created_at
# 0            52  ne0phyte   8/4/2016 11:52
# 1             1  vezycash  6/23/2016 22:20
# 2             1   hswarna   6/17/2016 0:01

# %%
import re

titles = hn["title"].tolist()
python_mentions = 0
pattern = "[Pp]ython"

for item in titles:
    if re.search(pattern, item):
        python_mentions += 1
        

python_mentions
# Out:
# 160

# %%
pattern = '[Pp]ython'
titles = hn['title']

python_mentions = titles.str.contains(pattern)
python_mentions.sum()
# Out:
# 160

# %%
titles = hn['title']
pattern = r'[Rr]uby'

ruby_titles = titles[titles.str.contains(pattern)]
ruby_titles.head()
# Out:
# 190                    Ruby on Google AppEngine Goes Beta
# 484          Related: Pure Ruby Relational Algebra Engine
# 1388    Show HN: HTTPalooza  Ruby's greatest HTTP clie...
# 1949    Rewriting a Ruby C Extension in Rust: How a Na...
# 2022    Show HN: CrashBreak  Reproduce exceptions as f...
# Name: title, dtype: object

# %%
email_bool = titles.str.contains(r'e-?mail')
email_count = email_bool.sum()
email_titles = titles[email_bool]
email_titles
# Out:
# 119      Show HN: Send an email from your shell to your...
# 313          Disposable emails for safe spam free shopping
# 1361     Ask HN: Doing cold emails? helps us prove this...
# 1750     Protect yourself from spam, bots and phishing ...
# 2421                    Ashley Madison hack treating email
#                                ...
# 18098    House panel looking into Reddit post about Cli...
# 18583    Mailgen  Generates clean, responsive HTML for ...
# 18847    Show HN: Crisp iOS keyboard for email and text...
# 19303    Ask HN: Why big email providers don't sign the...
# 19446    Tell HN: Secure email provider Riseup will run...
# Name: title, Length: 86, dtype: object

# %%
pattern = r'\[\w+\]'
tag_titles = titles[titles.str.contains(pattern)]
tag_count = tag_titles.shape[0]
tag_count
titles
# Out:
# 0                                Interactive Dynamic Video
# 1        Florida DJs May Face Felony for April Fools' W...
# 2             Technology ventures: From Idea to Enterprise
# 3        Note by Note: The Making of Steinway L1037 (2007)
# 4        Title II kills investment? Comcast and other I...
#                                ...
# 20094    How Purism Avoids Intels Active Management Tec...
# 20095            YC Application Translated and Broken Down
# 20096    Microkernels are slow and Elvis didn't do no d...
# 20097                        How Product Hunt really works
# 20098    RoboBrowser: Your friendly neighborhood web sc...
# Name: title, Length: 20099, dtype: object

# %%
pattern = r"\[(\w+)\]"
titles = hn["title"].str.extract(pattern)

tag_freq = titles[0].value_counts() 
tag_freq
# Out:
# pdf            276
# video          111
# audio            3
# 2015             3
# beta             2
# slides           2
# 2014             2
# SPA              1
# satire           1
# Benchmark        1
# SpaceX           1
# JavaScript       1
# Python           1
# Ubuntu           1
# NSFW             1
# GOST             1
# 2008             1
# HBR              1
# Skinnywhale      1
# React            1
# song             1
# Australian       1
# detainee         1
# German           1
# updated          1
# survey           1
# map              1
# 1996             1
# png              1
# Challenge        1
# Beta             1
# blank            1
# crash            1
# Excerpt          1
# transcript       1
# 5                1
# much             1
# Live             1
# CSS              1
# ANNOUNCE         1
# ask              1
# Infograph        1
# Map              1
# gif              1
# viz              1
# Petition         1
# repost           1
# ...

# %%
def first_10_matches(pattern):
    """
    Return the first 10 story titles that match
    the provided regular expression
    """
    all_matches = titles[titles.str.contains(pattern)]
    first_10 = all_matches.head(10)
    return first_10

#pattern = r"\[(\w+)\]"
#pattern = r"[Jj]ava[^Ss]"
pattern = r"(SQL)"
titles = hn["title"].str.extract(pattern, flags=re.I)

tag_freq = titles[0].value_counts() 
tag_freq
# Out:
# SQL    101
# Sql      4
# sql      3
# Name: 0, dtype: int64

# %%
hn_sql = hn[hn['title'].str.contains(r"\w+SQL", flags=re.I)].copy()
hn_sql
# Out:
#              id                                              title  \
# 142    10957172               PostgreSQL: Linux VS Windows  part 2
# 221    11544342               MemSQL (YC W11) Raises $36M Series C
# 882    10413272         Pgmemcahe :A PostgreSQL memcache functions
# 1160   10546681  How to choose an in-memory NoSQL solution: Per...
# 1197   11583183  Postgraphql: A GraphQL schema created by refle...
# 1370   10532855  MI6 (SIS) Is Developing a Node.js, Angular, No...
# 2430   12300670     Tracker: Ingesting MySQL data at scale  Part 2
# 2432   10361294             SQL for NoSQL: Couchbase N1QL Tutorial
# 4546   11437660  Finally, multiple synchronous replication for ...
# 4568   10725042   Getting started with NoSQL databases and MongoDB
# 4616   10674187  When are we going to contribute BDR to PostgreSQL
# 4944   10519135  SQL vs. NoSQL: you do want to have a relationa...
# 5398   12430768  Understanding the power of data types (Postgre...
# ...

# %%
pattern = r"(\w+SQL)"
sql_flavors = hn['title'].str.extract(pattern, flags=re.I)
tag_freq = sql_flavors[0].value_counts() 
tag_freq
# Out:
# PostgreSQL    27
# NoSQL         16
# MySQL         12
# mySql          1
# CloudSQL       1
# nosql          1
# SparkSQL       1
# MemSQL         1
# Name: 0, dtype: int64

# %%
hn_sql['flavor'] = hn['title'].str.extract(pattern, flags=re.I)
hn_sql['flavor'] = hn_sql['flavor'].str.lower()
hn_sql
# Out:
#              id                                              title  \
# 142    10957172               PostgreSQL: Linux VS Windows  part 2
# 221    11544342               MemSQL (YC W11) Raises $36M Series C
# 882    10413272         Pgmemcahe :A PostgreSQL memcache functions
# 1160   10546681  How to choose an in-memory NoSQL solution: Per...
# 1197   11583183  Postgraphql: A GraphQL schema created by refle...
# 1370   10532855  MI6 (SIS) Is Developing a Node.js, Angular, No...
# 2430   12300670     Tracker: Ingesting MySQL data at scale  Part 2
# 2432   10361294             SQL for NoSQL: Couchbase N1QL Tutorial
# 4546   11437660  Finally, multiple synchronous replication for ...
# 4568   10725042   Getting started with NoSQL databases and MongoDB
# 4616   10674187  When are we going to contribute BDR to PostgreSQL
# 4944   10519135  SQL vs. NoSQL: you do want to have a relationa...
# 5398   12430768  Understanding the power of data types (Postgre...
# ...

# %%
sql_pivot = hn_sql.pivot_table(index='flavor', values='num_comments')
sql_pivot
# Out:
#             num_comments
# flavor
# cloudsql        5.000000
# memsql         14.000000
# mysql          12.230769
# nosql          14.529412
# postgresql     25.962963
# sparksql        1.000000

# %%
#pattern = r"(\w+[Pp]ython [\d\.]+)"
pattern = r"[Pp]ython ([\d\.]+)"
py_versions = hn['title'].str.extract(pattern, flags=re.I)
py_versions_freq = dict(py_versions[0].value_counts())
py_versions_freq
# Out:
# {'3': 10,
#  '2': 3,
#  '3.5': 3,
#  '3.6': 2,
#  '3.5.0': 1,
#  '1.5': 1,
#  '4': 1,
#  '2.7': 1,
#  '8': 1}

# %%
def first_10_matches(pattern):
    """
    Return the first 10 story titles that match
    the provided regular expression
    """
    all_matches = hn['title'][hn['title'].str.contains(pattern)]
    first_10 = all_matches.head(10)
    return first_10

pattern = r"\b[Cc]\b[^.+]"
first_ten = first_10_matches(pattern)
first_ten
# Out:
# 365                      The new C standards are worth it
# 444           Moz raises $10m Series C from Foundry Group
# 521          Fuchsia: Micro kernel written in C by Google
# 1307            Show HN: Yupp, yet another C preprocessor
# 1326                     The C standard formalized in Coq
# 1365                          GNU C Library 2.23 released
# 1429    Cysignals: signal handling (SIGINT, SIGSEGV, )...
# 1620                        SDCC  Small Device C Compiler
# 1949    Rewriting a Ruby C Extension in Rust: How a Na...
# 2195    MyHTML  HTML Parser on Pure C with POSIX Threa...
# Name: title, dtype: object

# %% [markdown]
# #  Write a regular expression and assign it to pattern. The regular expression should:
#
#     Match instances of C or c where they are not preceded or followed by another word character.
#     Exclude instances where the match is followed by a . or + character, without removing instances where the match occurs at the end of the string.
#     Exclude instances where the word 'Series' immediately precedes the match.

# %%
pattern = r"(?<!Series\s)\b[Cc]\b(?![\+\.\-\/])"
c_mentions = hn['title'][hn['title'].str.contains(pattern)]
c_mentions
# Out:
# 365                       The new C standards are worth it
# 521           Fuchsia: Micro kernel written in C by Google
# 1307             Show HN: Yupp, yet another C preprocessor
# 1326                      The C standard formalized in Coq
# 1365                           GNU C Library 2.23 released
#                                ...
# 18479    Tis-interpreter detects subtle bugs in C programs
# 18480                                             Fixing C
# 18549            Show HN: An awesome C library for Windows
# 19151                      Ask HN: How to learn C in 2016?
# 19933    Lightweight C library to parse NMEA 0183 sente...
# Name: title, Length: 94, dtype: object

# %% [markdown]
# # Write a regular expression to match cases of repeated words:
#
#     We'll define a word as a series of one or more word characters that are preceded and followed by a boundary anchor.
#     We'll define repeated words as the same word repeated twice, separated by a whitespace character.

# %%
pattern = r"\b(\w+)\s\1\b"

repeated_words = hn['title'][hn['title'].str.contains(pattern)]
repeated_words
# Out:
# 3102                  Silicon Valley Has a Problem Problem
# 3176                Wire Wire: A West African Cyber Threat
# 3178                         Flexbox Cheatsheet Cheatsheet
# 4797                            The Mindset Mindset (2015)
# 7276     Valentine's Day Special: Bye Bye Tinder, Flirt...
# 10371    Mcdonalds copying cyriak  cows cows cows in th...
# 11575                                    Bang Bang Control
# 11901          Cordless Telephones: Bye Bye Privacy (1991)
# 12697          Solving the the Monty-Hall-Problem in Swift
# 15049    Bye Bye Webrtc2SIP: WebRTC with Asterisk and A...
# 15839          Intellij-Rust Rust Plugin for IntelliJ IDEA
# Name: title, dtype: object

# %%
email_variations = pd.Series(['email', 'Email', 'e Mail',
                        'e mail', 'E-mail', 'e-mail',
                        'eMail', 'E-Mail', 'EMAIL'])

pattern = r"e[\-\s]?mail"
email_uniform = email_variations.str.replace(pattern, "email", flags=re.I)
titles_clean = hn['title'].str.replace(pattern, "email", flags=re.I)
email_uniform
# Out:
# 0    email
# 1    email
# 2    email
# 3    email
# 4    email
# 5    email
# 6    email
# 7    email
# 8    email
# dtype: object

# %%
test_urls = pd.Series([
 'https://www.amazon.com/Technology-Ventures-Enterprise-Thomas-Byers/dp/0073523429',
 'http://www.interactivedynamicvideo.com/',
 'http://www.nytimes.com/2007/11/07/movies/07stein.html?_r=0',
 'http://evonomics.com/advertising-cannot-maintain-internet-heres-solution/',
 'HTTPS://github.com/keppel/pinn',
 'Http://phys.org/news/2015-09-scale-solar-youve.html',
 'https://iot.seeed.cc',
 'http://www.bfilipek.com/2016/04/custom-deleters-for-c-smart-pointers.html',
 'http://beta.crowdfireapp.com/?beta=agnipath',
 'https://www.valid.ly?param',
 'http://css-cursor.techstream.org'
])
pattern = r"https?://([\w\-\.]+)"
test_urls_clean = test_urls.str.extract(pattern, flags=re.I)
test_urls_clean
domains = hn['url'].str.extract(pattern, flags=re.I)
top_domains = domains[0].value_counts().head(5)
#top_domains
test_urls_clean
# Out:
#                                   0
# 0                    www.amazon.com
# 1   www.interactivedynamicvideo.com
# 2                   www.nytimes.com
# 3                     evonomics.com
# 4                        github.com
# 5                          phys.org
# 6                      iot.seeed.cc
# 7                  www.bfilipek.com
# 8             beta.crowdfireapp.com
# 9                      www.valid.ly
# 10        css-cursor.techstream.org

# %%
pattern = r"(https?)://([\w\.\-]+)/?(.*)"
test_url_parts = test_urls.str.extract(pattern, flags=re.I)
url_parts = hn['url'].str.extract(pattern, flags=re.I)
url_parts
# Out:
#            0                                1  \
# 0       http  www.interactivedynamicvideo.com
# 1       http                  www.thewire.com
# 2      https                   www.amazon.com
# 3       http                  www.nytimes.com
# 4       http                  arstechnica.com
# ...      ...                              ...
# 20094  https                          puri.sm
# 20095  https                       medium.com
# 20096   http               blog.darknedgy.net
# 20097  https                       medium.com
# 20098  https                       github.com
#
#                                                        2
# 0
# 1      entertainment/2013/04/florida-djs-april-fools-...
# 2      Technology-Ventures-Enterprise-Thomas-Byers/dp...
# 3                    2007/11/07/movies/07stein.html?_r=0
# 4      business/2015/10/comcast-and-other-isps-boost-...
# ...                                                  ...
# 20094  philosophy/how-purism-avoids-intels-active-man...
# ...

# %%
pattern = r"(?P<protocol>https?)://(?P<domain>[\w\.\-]+)/?(?P<path>.*)"
url_parts = hn['url'].str.extract(pattern, flags=re.I)
url_parts
# Out:
#       protocol                           domain  \
# 0         http  www.interactivedynamicvideo.com
# 1         http                  www.thewire.com
# 2        https                   www.amazon.com
# 3         http                  www.nytimes.com
# 4         http                  arstechnica.com
# ...        ...                              ...
# 20094    https                          puri.sm
# 20095    https                       medium.com
# 20096     http               blog.darknedgy.net
# 20097    https                       medium.com
# 20098    https                       github.com
#
#                                                     path
# 0
# 1      entertainment/2013/04/florida-djs-april-fools-...
# 2      Technology-Ventures-Enterprise-Thomas-Byers/dp...
# 3                    2007/11/07/movies/07stein.html?_r=0
# 4      business/2015/10/comcast-and-other-isps-boost-...
# ...                                                  ...
# ...
